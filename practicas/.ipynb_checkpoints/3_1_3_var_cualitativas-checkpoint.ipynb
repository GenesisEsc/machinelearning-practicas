# %% [markdown]
# ![Logo](img/logoitqv1.jpg)
#
# 01PAO26-26 - Variables Cualitativas
#
# ![logo](img/python_logo.png)
#
# [Génesis Escobar](https://github.com/GenesisEsc/machinelearning-practicas/tree/main/practicas)

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Master' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Doctorado' 'Master' 'Grado' 'Master' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Doctorado' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Master' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Grado' 'Master' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Doctorado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Master' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Master' 'Bachillerato' 'Master' 'Master'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creamos el DataFrame a partir de tu lista original 'nivel_estudios'
df = pd.DataFrame(nivel_estudios, columns=['Nivel'])
df
# Out:
#             Nivel
# 0    Bachillerato
# 1    Bachillerato
# 2    Bachillerato
# 3          Master
# 4           Grado
# ..            ...
# 495     Doctorado
# 496    Secundaria
# 497         Grado
# 498         Grado
# 499    Secundaria
#
# [500 rows x 1 columns]

# %%
# Calculamos las frecuencias de forma automática
frecuencias = df['Nivel'].value_counts()

# %%
# Mostrar la tabla de frecuencias (opcional pero útil)
print("Tabla de Frecuencias:")
print(frecuencias)
# Out:
# Tabla de Frecuencias:
# Nivel
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Diagrama de Barras con Pandas
frecuencias.plot(kind='bar', ax=ax1, color='skyblue', edgecolor='black')
ax1.set_title('Diagrama de Barras (Pandas)')
ax1.set_xlabel('Nivel de estudios')
ax1.set_ylabel('Frecuencia absoluta')
ax1.tick_params(axis='x', rotation=45)

# Diagrama de Sectores con Pandas
frecuencias.plot(kind='pie', ax=ax2, autopct='%1.1f%%', 
                 startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])
ax2.set_title('Diagrama de Sectores (Pandas)')
ax2.set_ylabel('') 

plt.tight_layout()
plt.show()
